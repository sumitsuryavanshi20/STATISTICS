# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("IRIS.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.head()
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
df.shape
# Out:
# (150, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
sub_df = df[['sepal_length', 'sepal_width',	'petal_length',	'petal_width',	'species']]
sub_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
sub_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# QUESTION.1 Without directly calculating the mean, determine which sepal measurement (sepal_length or sepal_width) has a higher average by observing the dataset.
mean = sub_df['sepal_length'].mean(), sub_df['sepal_width'].mean()
(mean)
#ANSWER speal_length has higher average mean.
# Out:
# (5.843333333333334, 3.0540000000000003)

# %%
# QUESTION.2 Compare the variability of petal measurements by checking the difference between the ranges of petal_length and petal_width. Which feature shows more spread?

L = sub_df['petal_length'].max()
L
# Out:
# 6.9

# %%
S = sub_df['petal_width'].min()
S
# Out:
# 0.1

# %%
range = L - S
range
#ANSWER petal_length has more spread.
# Out:
# 6.800000000000001

# %%
# QUESTION.3 Identify which feature, sepal_length or sepal_width, has a higher interquartile range (IQR), indicating greater variability in the middle 50% of the data.
q1 = sub_df['sepal_length'].quantile(0.50)
q1
# Out:
# 5.8

# %%
q3 = sub_df['sepal_width'].quantile(0.50)
q3
# Out:
# 3.0

# %%
iqr = q3-q1
iqr
# Out:
# -2.8

# %%
# QUESTION.4 Based on the computed standard deviations of sepal_length and sepal_width, determine which attribute exhibits more variability and discuss what this indicates about the consistency of the two features.
sd = sub_df['sepal_length'].std()
sd
# Out:
# 0.8280661279778629

# %%
sub_df['sepal_width'].std()
sd
# Out:
# 0.8280661279778629

# %%
#QUESTION.5 Without plotting, assess whether the petal_length distribution is skewed. Use a descriptive statistic that measures skewness and infer the distribution shape.
skew = sub_df['petal_length'].skew()
skew
# Out:
# -0.27446425247378287

# %%
#QUESTION.6 For which attribute, sepal_length or sepal_width, is the skewness closer to zero? What does this imply about the symmetry of its distribution?
skew = sub_df['sepal_length'].skew(), sub_df['sepal_width'].skew()
skew
#Speal_length is close to zero.
# Out:
# (0.3149109566369728, 0.3340526621720866)

# %%
#Calculate the coefficient of variation (CV) for sepal_length and petal_length. Which feature has greater relative variability, and what does this tell you about the dataset?
cv = sub_df['sepal_length'].std(),(sub_df['petal_length'].mean())
cv
# Out:
# (0.8280661279778629, 3.758666666666666)

# %%
#Identify the outliers in the sepal_length feature using the IQR method (define outliers as values that fall below Q1 - 1.5 * IQR or above Q3 + 1.5 * IQR). How many outliers are present?
Se_iqr = sub_df['sepal_length'].quantile(0.75) - sub_df['sepal_length'].quantile(0.25)
Se_iqr
upper_fence = sub_df['sepal_length'].quantile(0.75) + 1.5 * Se_iqr
upper_fence
lower_fence = sub_df['sepal_length'].quantile(0.25) - 1.5 * Se_iqr
lower_fence
outliers = sub_df[(sub_df['sepal_length'] > upper_fence) |
                  (sub_df['sepal_length'] < lower_fence)]
print("outliers rows:")
print(outliers)
numoutliers = outliers.shape[0]
print("Number of outliers:", numoutliers)
# Out:
# outliers rows:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width, species]
# Index: []
# Number of outliers: 0
